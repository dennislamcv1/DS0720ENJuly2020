# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("darkgrid")


# %matplotlib inline

# %%
df = pd.read_csv("BX.csv", low_memory=False)

# %%
df
# Out:
#       Borough  Block   Lot   CD  CT2010  CB2010  SchoolDist  Council  ZipCode  \
# 0          BX   2260     1  201    19.0  1022.0         7.0      8.0  10454.0
# 1          BX   2260     4  201    19.0  1022.0         7.0      8.0  10454.0
# 2          BX   2260    10  201    19.0  1022.0         7.0      8.0  10454.0
# 3          BX   2260    17  201    19.0  1022.0         7.0      8.0  10454.0
# 4          BX   2260    18  201    19.0  1022.0         7.0      8.0  10454.0
# ...       ...    ...   ...  ...     ...     ...         ...      ...      ...
# 89849      BX   9999   100  204     NaN     NaN         NaN      NaN      NaN
# 89850      BX   9999   150  205     NaN     NaN         NaN      NaN      NaN
# 89851      BX   9999   200  205     NaN     NaN         NaN      NaN      NaN
# 89852      BX   9999  8900  209     NaN     NaN         NaN      NaN      NaN
# 89853      BX      0  8900  208     NaN     NaN         NaN      NaN      NaN
#
# ...

# %%
df = df[['Address', 'BldgArea', 'BldgDepth', 'BuiltFAR', 'CommFAR', 'FacilFAR', 'Lot', 'LotArea', 
         'LotDepth', 'NumBldgs', 'NumFloors', 'OfficeArea', 'ResArea', 'ResidFAR', 'RetailArea', 
         'YearBuilt', 'YearAlter1', 'ZipCode', 'YCoord', 'XCoord']]

# %%
df
# Out:
#                       Address  BldgArea  BldgDepth  BuiltFAR  CommFAR  \
# 0      122 BRUCKNER BOULEVARD         0        0.0      0.00      5.0
# 1      126 BRUCKNER BOULEVARD       752       16.0      0.05      5.0
# 2      138 BRUCKNER BOULEVARD     39375      200.0      1.13      5.0
# 3      144 BRUCKNER BOULEVARD     12500       85.0      5.00      5.0
# 4      148 BRUCKNER BOULEVARD      8595       70.0      4.58      5.0
# ...                       ...       ...        ...       ...      ...
# 89849                     NaN         0        0.0      0.00      0.0
# 89850                     NaN         0        0.0      0.00      3.4
# 89851                     NaN         0        0.0      0.00      0.0
# 89852                     NaN         0        0.0      0.00      0.0
# 89853                     NaN         0        0.0      0.00      0.0
#
#        FacilFAR   Lot  LotArea  LotDepth  NumBldgs  NumFloors  OfficeArea  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89854 entries, 0 to 89853
# Data columns (total 20 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Address     89785 non-null  object
#  1   BldgArea    89854 non-null  int64
#  2   BldgDepth   89854 non-null  float64
#  3   BuiltFAR    89854 non-null  float64
#  4   CommFAR     89854 non-null  float64
#  5   FacilFAR    89854 non-null  float64
#  6   Lot         89854 non-null  int64
#  7   LotArea     89854 non-null  int64
#  8   LotDepth    89854 non-null  float64
#  9   NumBldgs    89854 non-null  int64
#  10  NumFloors   89854 non-null  float64
#  11  OfficeArea  89854 non-null  int64
#  12  ResArea     89854 non-null  int64
#  13  ResidFAR    89854 non-null  float64
#  14  RetailArea  89854 non-null  int64
#  15  YearBuilt   89854 non-null  int64
#  16  YearAlter1  89854 non-null  int64
#  17  ZipCode     89525 non-null  float64
#  18  YCoord      86595 non-null  float64
# ...

# %%
df1 = df.copy()

# %%
df1
# Out:
#                       Address  BldgArea  BldgDepth  BuiltFAR  CommFAR  \
# 0      122 BRUCKNER BOULEVARD         0        0.0      0.00      5.0
# 1      126 BRUCKNER BOULEVARD       752       16.0      0.05      5.0
# 2      138 BRUCKNER BOULEVARD     39375      200.0      1.13      5.0
# 3      144 BRUCKNER BOULEVARD     12500       85.0      5.00      5.0
# 4      148 BRUCKNER BOULEVARD      8595       70.0      4.58      5.0
# ...                       ...       ...        ...       ...      ...
# 89849                     NaN         0        0.0      0.00      0.0
# 89850                     NaN         0        0.0      0.00      3.4
# 89851                     NaN         0        0.0      0.00      0.0
# 89852                     NaN         0        0.0      0.00      0.0
# 89853                     NaN         0        0.0      0.00      0.0
#
#        FacilFAR   Lot  LotArea  LotDepth  NumBldgs  NumFloors  OfficeArea  \
# ...

# %%
df1.dropna(inplace=True)

# %%
df1
# Out:
#                       Address  BldgArea  BldgDepth  BuiltFAR  CommFAR  \
# 0      122 BRUCKNER BOULEVARD         0       0.00      0.00      5.0
# 1      126 BRUCKNER BOULEVARD       752      16.00      0.05      5.0
# 2      138 BRUCKNER BOULEVARD     39375     200.00      1.13      5.0
# 3      144 BRUCKNER BOULEVARD     12500      85.00      5.00      5.0
# 4      148 BRUCKNER BOULEVARD      8595      70.00      4.58      5.0
# ...                       ...       ...        ...       ...      ...
# 89840   6007 RIVERDALE AVENUE      1044      29.00      0.55      0.0
# 89842   6301 RIVERDALE AVENUE    237021      35.00      0.13      0.0
# 89843     755 WEST 261 STREET     83366     121.75      0.32      0.0
# 89844    755 RIVERDALE AVENUE         0       0.00      0.00      0.0
# 89845    537A WEST 261 STREET       903      24.75      0.05      0.0
#
#        FacilFAR  Lot  LotArea  LotDepth  NumBldgs  NumFloors  OfficeArea  \
# ...

# %%
df1.columns
# Out:
# Index(['Address', 'BldgArea', 'BldgDepth', 'BuiltFAR', 'CommFAR', 'FacilFAR',
#        'Lot', 'LotArea', 'LotDepth', 'NumBldgs', 'NumFloors', 'OfficeArea',
#        'ResArea', 'ResidFAR', 'RetailArea', 'YearBuilt', 'YearAlter1',
#        'ZipCode', 'YCoord', 'XCoord'],
#       dtype='object')

# %%
df1.drop(['Address','YCoord', 'XCoord'],axis=1,inplace=True)

# %%
df1
# Out:
#        BldgArea  BldgDepth  BuiltFAR  CommFAR  FacilFAR  Lot  LotArea  \
# 0             0       0.00      0.00      5.0       6.5    1    15000
# 1           752      16.00      0.05      5.0       6.5    4    13770
# 2         39375     200.00      1.13      5.0       6.5   10    35000
# 3         12500      85.00      5.00      5.0       6.5   17     2500
# 4          8595      70.00      4.58      5.0       6.5   18     1875
# ...         ...        ...       ...      ...       ...  ...      ...
# 89840      1044      29.00      0.55      0.0       2.0  877     1900
# 89842    237021      35.00      0.13      0.0       2.0    1  1845000
# 89843     83366     121.75      0.32      0.0       2.0   10   257775
# 89844         0       0.00      0.00      0.0       2.0   43    14749
# 89845       903      24.75      0.05      0.0       2.0   65    18962
#
#        LotDepth  NumBldgs  NumFloors  OfficeArea  ResArea  ResidFAR  \
# ...

# %%
df2 = pd.read_csv("Q2.csv")

# %%
df2
# Out:
#         Complaint Type  Incident Zip          Street Name Borough
# 0       HEAT/HOT WATER       10458.0   SOUTHERN BOULEVARD   BRONX
# 1       HEAT/HOT WATER       10456.0        MORRIS AVENUE   BRONX
# 2       HEAT/HOT WATER       10459.0         ALDUS STREET   BRONX
# 3       HEAT/HOT WATER       10473.0       BOYNTON AVENUE   BRONX
# 4       HEAT/HOT WATER       10463.0  KINGSBRIDGE TERRACE   BRONX
# ...                ...           ...                  ...     ...
# 606128  HEAT/HOT WATER       10452.0    WOODYCREST AVENUE   BRONX
# 606129  HEAT/HOT WATER       10470.0     EAST  242 STREET   BRONX
# 606130  HEAT/HOT WATER       10458.0    BAINBRIDGE AVENUE   BRONX
# 606131  HEAT/HOT WATER       10461.0   BRUCKNER BOULEVARD   BRONX
# 606132  HEAT/HOT WATER       10467.0   WEST GUN HILL ROAD   BRONX
#
# [606133 rows x 4 columns]

# %%
df2.columns
# Out:
# Index(['Complaint Type', 'Incident Zip', 'Street Name', 'Borough'], dtype='object')

# %%
df2.drop(['Complaint Type','Borough'],axis=1,inplace=True)

# %%
df2
# Out:
#         Incident Zip          Street Name
# 0            10458.0   SOUTHERN BOULEVARD
# 1            10456.0        MORRIS AVENUE
# 2            10459.0         ALDUS STREET
# 3            10473.0       BOYNTON AVENUE
# 4            10463.0  KINGSBRIDGE TERRACE
# ...              ...                  ...
# 606128       10452.0    WOODYCREST AVENUE
# 606129       10470.0     EAST  242 STREET
# 606130       10458.0    BAINBRIDGE AVENUE
# 606131       10461.0   BRUCKNER BOULEVARD
# 606132       10467.0   WEST GUN HILL ROAD
#
# [606133 rows x 2 columns]

# %%
df2["Street Name"].value_counts()
# Out:
# GRAND CONCOURSE             33374
# MORRIS AVENUE               14166
# BOYNTON AVENUE              10668
# BAILEY AVENUE                9332
# DR M L KING JR BOULEVARD     9105
#                             ...
# SOUTH 6 AVE                     1
# HAWKINS STREET                  1
# ROHR PLACE                      1
# BEDFORD AVE                     1
# SUMMIT PLACE                    1
# Name: Street Name, Length: 1237, dtype: int64

# %%
df2["Incident Zip"].value_counts()
# Out:
# 10467.0    57190
# 10458.0    56992
# 10468.0    50670
# 10453.0    49938
# 10452.0    43309
# 10457.0    40648
# 10456.0    38073
# 10462.0    35322
# 10463.0    30185
# 10472.0    29796
# 10460.0    28130
# 10451.0    23186
# 10466.0    21170
# 10459.0    19937
# 10455.0    15139
# 10461.0    14098
# 10454.0     9719
# 10469.0     9054
# 10473.0     8625
# 10470.0     6911
# 10474.0     5144
# 10471.0     3616
# 10465.0     2157
# 10475.0      794
# 10464.0      340
# 10803.0        4
# Name: Incident Zip, dtype: int64

# %%
duplicateDFRow = df2[df2.duplicated()]

# %%
duplicateDFRow
# Out:
#         Incident Zip         Street Name
# 6            10462.0    BRONXDALE AVENUE
# 13           10453.0      BUCHANAN PLACE
# 16           10462.0    BRONXDALE AVENUE
# 18           10468.0   UNIVERSITY AVENUE
# 23           10453.0     GRAND CONCOURSE
# ...              ...                 ...
# 606128       10452.0   WOODYCREST AVENUE
# 606129       10470.0    EAST  242 STREET
# 606130       10458.0   BAINBRIDGE AVENUE
# 606131       10461.0  BRUCKNER BOULEVARD
# 606132       10467.0  WEST GUN HILL ROAD
#
# [603836 rows x 2 columns]

# %%
df2.drop_duplicates(ignore_index=True, inplace=True)

# %%
df2
# Out:
#       Incident Zip          Street Name
# 0          10458.0   SOUTHERN BOULEVARD
# 1          10456.0        MORRIS AVENUE
# 2          10459.0         ALDUS STREET
# 3          10473.0       BOYNTON AVENUE
# 4          10463.0  KINGSBRIDGE TERRACE
# ...            ...                  ...
# 2292       10471.0     GOODRIDGE AVENUE
# 2293       10469.0       DEMEYER STREET
# 2294       10461.0        HASKIN STREET
# 2295       10456.0       GRANDCONCOURSE
# 2296       10453.0           ECHO PLACE
#
# [2297 rows x 2 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2297 entries, 0 to 2296
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Incident Zip  1713 non-null   float64
#  1   Street Name   2296 non-null   object
# dtypes: float64(1), object(1)
# memory usage: 36.0+ KB

# %%
df2.rename(columns={'Incident Zip':'ZipCode'}, inplace=True)

# %%
df2
# Out:
#       ZipCode          Street Name
# 0     10458.0   SOUTHERN BOULEVARD
# 1     10456.0        MORRIS AVENUE
# 2     10459.0         ALDUS STREET
# 3     10473.0       BOYNTON AVENUE
# 4     10463.0  KINGSBRIDGE TERRACE
# ...       ...                  ...
# 2292  10471.0     GOODRIDGE AVENUE
# 2293  10469.0       DEMEYER STREET
# 2294  10461.0        HASKIN STREET
# 2295  10456.0       GRANDCONCOURSE
# 2296  10453.0           ECHO PLACE
#
# [2297 rows x 2 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2297 entries, 0 to 2296
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ZipCode      1713 non-null   float64
#  1   Street Name  2296 non-null   object
# dtypes: float64(1), object(1)
# memory usage: 36.0+ KB

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 86591 entries, 0 to 89845
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   BldgArea    86591 non-null  int64
#  1   BldgDepth   86591 non-null  float64
#  2   BuiltFAR    86591 non-null  float64
#  3   CommFAR     86591 non-null  float64
#  4   FacilFAR    86591 non-null  float64
#  5   Lot         86591 non-null  int64
#  6   LotArea     86591 non-null  int64
#  7   LotDepth    86591 non-null  float64
#  8   NumBldgs    86591 non-null  int64
#  9   NumFloors   86591 non-null  float64
#  10  OfficeArea  86591 non-null  int64
#  11  ResArea     86591 non-null  int64
#  12  ResidFAR    86591 non-null  float64
#  13  RetailArea  86591 non-null  int64
#  14  YearBuilt   86591 non-null  int64
#  15  YearAlter1  86591 non-null  int64
#  16  ZipCode     86591 non-null  float64
# dtypes: float64(8), int64(9)
# memory usage: 11.9 MB

# %%
df3 = pd.merge(left=df1,right=df2,how='inner',on="ZipCode")

# %%
df3
# Out:
#          BldgArea  BldgDepth  BuiltFAR  CommFAR  FacilFAR  Lot  LotArea  \
# 0               0       0.00      0.00      5.0       6.5    1    15000
# 1               0       0.00      0.00      5.0       6.5    1    15000
# 2               0       0.00      0.00      5.0       6.5    1    15000
# 3               0       0.00      0.00      5.0       6.5    1    15000
# 4               0       0.00      0.00      5.0       6.5    1    15000
# ...           ...        ...       ...      ...       ...  ...      ...
# 6935930       903      24.75      0.05      0.0       2.0   65    18962
# 6935931       903      24.75      0.05      0.0       2.0   65    18962
# 6935932       903      24.75      0.05      0.0       2.0   65    18962
# 6935933       903      24.75      0.05      0.0       2.0   65    18962
# 6935934       903      24.75      0.05      0.0       2.0   65    18962
#
#          LotDepth  NumBldgs  NumFloors  OfficeArea  ResArea  ResidFAR  \
# ...

# %%
df3.isnull().sum()
# Out:
# BldgArea       0
# BldgDepth      0
# BuiltFAR       0
# CommFAR        0
# FacilFAR       0
# Lot            0
# LotArea        0
# LotDepth       0
# NumBldgs       0
# NumFloors      0
# OfficeArea     0
# ResArea        0
# ResidFAR       0
# RetailArea     0
# YearBuilt      0
# YearAlter1     0
# ZipCode        0
# Street Name    0
# dtype: int64

# %%
duplicateDFRow = df3[df3.duplicated()]

# %%
duplicateDFRow
# Out:
#          BldgArea  BldgDepth  BuiltFAR  CommFAR  FacilFAR  Lot  LotArea  \
# 43104           0        0.0      0.00      2.0       3.0   22     2500
# 43105           0        0.0      0.00      2.0       3.0   22     2500
# 43106           0        0.0      0.00      2.0       3.0   22     2500
# 43107           0        0.0      0.00      2.0       3.0   22     2500
# 43108           0        0.0      0.00      2.0       3.0   22     2500
# ...           ...        ...       ...      ...       ...  ...      ...
# 6718071      1800       45.0      0.95      0.0       2.0   46     1900
# 6718072      1800       45.0      0.95      0.0       2.0   46     1900
# 6718073      1800       45.0      0.95      0.0       2.0   46     1900
# 6718074      1800       45.0      0.95      0.0       2.0   46     1900
# 6718075      1800       45.0      0.95      0.0       2.0   46     1900
#
#          LotDepth  NumBldgs  NumFloors  OfficeArea  ResArea  ResidFAR  \
# ...

# %%
df3.drop_duplicates(ignore_index=True, inplace=True)

# %%
df3
# Out:
#          BldgArea  BldgDepth  BuiltFAR  CommFAR  FacilFAR  Lot  LotArea  \
# 0               0       0.00      0.00      5.0       6.5    1    15000
# 1               0       0.00      0.00      5.0       6.5    1    15000
# 2               0       0.00      0.00      5.0       6.5    1    15000
# 3               0       0.00      0.00      5.0       6.5    1    15000
# 4               0       0.00      0.00      5.0       6.5    1    15000
# ...           ...        ...       ...      ...       ...  ...      ...
# 6929537       903      24.75      0.05      0.0       2.0   65    18962
# 6929538       903      24.75      0.05      0.0       2.0   65    18962
# 6929539       903      24.75      0.05      0.0       2.0   65    18962
# 6929540       903      24.75      0.05      0.0       2.0   65    18962
# 6929541       903      24.75      0.05      0.0       2.0   65    18962
#
#          LotDepth  NumBldgs  NumFloors  OfficeArea  ResArea  ResidFAR  \
# ...

# %%
df3.groupby(by="ZipCode").count()
# Out:
#          BldgArea  BldgDepth  BuiltFAR  CommFAR  FacilFAR      Lot  LotArea  \
# ZipCode
# 10451.0     64068      64068     64068    64068     64068    64068    64068
# 10452.0    121196     121196    121196   121196    121196   121196   121196
# 10453.0    165321     165321    165321   165321    165321   165321   165321
# 10454.0     79008      79008     79008    79008     79008    79008    79008
# 10455.0     98056      98056     98056    98056     98056    98056    98056
# 10456.0    182000     182000    182000   182000    182000   182000   182000
# 10457.0    227612     227612    227612   227612    227612   227612   227612
# 10458.0    223122     223122    223122   223122    223122   223122   223122
# 10459.0    144951     144951    144951   144951    144951   144951   144951
# 10460.0    232649     232649    232649   232649    232649   232649   232649
# 10461.0    841915     841915    841915   841915    841915   841915   841915
# ...

# %%
df3.groupby(by="Street Name").count()
# Out:
#                  BldgArea  BldgDepth  BuiltFAR  CommFAR  FacilFAR    Lot  \
# Street Name
# 173 STREET           4249       4249      4249     4249      4249   4249
# 226 DRIVE            8965       8965      8965     8965      8965   8965
# 229 DRIVE NORTH      8965       8965      8965     8965      8965   8965
# 229 DRIVE SOUTH      8965       8965      8965     8965      8965   8965
# 3 AVENUE            12998      12998     12998    12998     12998  12998
# ...                   ...        ...       ...      ...       ...    ...
# WYTHE PLACE          1478       1478      1478     1478      1478   1478
# YATES AVENUE        18385      18385     18385    18385     18385  18385
# YOUNG AVENUE        11064      11064     11064    11064     11064  11064
# ZEREGA AVENUE        9225       9225      9225     9225      9225   9225
# ZULETTE AVENUE       7321       7321      7321     7321      7321   7321
#
# ...

# %%
df4 = df3.copy()

# %%
df4
# Out:
#          BldgArea  BldgDepth  BuiltFAR  CommFAR  FacilFAR  Lot  LotArea  \
# 0               0       0.00      0.00      5.0       6.5    1    15000
# 1               0       0.00      0.00      5.0       6.5    1    15000
# 2               0       0.00      0.00      5.0       6.5    1    15000
# 3               0       0.00      0.00      5.0       6.5    1    15000
# 4               0       0.00      0.00      5.0       6.5    1    15000
# ...           ...        ...       ...      ...       ...  ...      ...
# 6929537       903      24.75      0.05      0.0       2.0   65    18962
# 6929538       903      24.75      0.05      0.0       2.0   65    18962
# 6929539       903      24.75      0.05      0.0       2.0   65    18962
# 6929540       903      24.75      0.05      0.0       2.0   65    18962
# 6929541       903      24.75      0.05      0.0       2.0   65    18962
#
#          LotDepth  NumBldgs  NumFloors  OfficeArea  ResArea  ResidFAR  \
# ...

# %%
df4.drop(['Street Name'],axis=1,inplace=True)

# %%
df4
# Out:
#          BldgArea  BldgDepth  BuiltFAR  CommFAR  FacilFAR  Lot  LotArea  \
# 0               0       0.00      0.00      5.0       6.5    1    15000
# 1               0       0.00      0.00      5.0       6.5    1    15000
# 2               0       0.00      0.00      5.0       6.5    1    15000
# 3               0       0.00      0.00      5.0       6.5    1    15000
# 4               0       0.00      0.00      5.0       6.5    1    15000
# ...           ...        ...       ...      ...       ...  ...      ...
# 6929537       903      24.75      0.05      0.0       2.0   65    18962
# 6929538       903      24.75      0.05      0.0       2.0   65    18962
# 6929539       903      24.75      0.05      0.0       2.0   65    18962
# 6929540       903      24.75      0.05      0.0       2.0   65    18962
# 6929541       903      24.75      0.05      0.0       2.0   65    18962
#
#          LotDepth  NumBldgs  NumFloors  OfficeArea  ResArea  ResidFAR  \
# ...

# %%
duplicateDFRow = df4[df4.duplicated()]

# %%
duplicateDFRow
# Out:
#          BldgArea  BldgDepth  BuiltFAR  CommFAR  FacilFAR  Lot  LotArea  \
# 1               0       0.00      0.00      5.0       6.5    1    15000
# 2               0       0.00      0.00      5.0       6.5    1    15000
# 3               0       0.00      0.00      5.0       6.5    1    15000
# 4               0       0.00      0.00      5.0       6.5    1    15000
# 5               0       0.00      0.00      5.0       6.5    1    15000
# ...           ...        ...       ...      ...       ...  ...      ...
# 6929537       903      24.75      0.05      0.0       2.0   65    18962
# 6929538       903      24.75      0.05      0.0       2.0   65    18962
# 6929539       903      24.75      0.05      0.0       2.0   65    18962
# 6929540       903      24.75      0.05      0.0       2.0   65    18962
# 6929541       903      24.75      0.05      0.0       2.0   65    18962
#
#          LotDepth  NumBldgs  NumFloors  OfficeArea  ResArea  ResidFAR  \
# ...

# %%
df4.drop_duplicates(ignore_index=True, inplace=True)

# %%
df4
# Out:
#        BldgArea  BldgDepth  BuiltFAR  CommFAR  FacilFAR  Lot  LotArea  \
# 0             0       0.00      0.00      5.0       6.5    1    15000
# 1           752      16.00      0.05      5.0       6.5    4    13770
# 2         39375     200.00      1.13      5.0       6.5   10    35000
# 3         12500      85.00      5.00      5.0       6.5   17     2500
# 4          8595      70.00      4.58      5.0       6.5   18     1875
# ...         ...        ...       ...      ...       ...  ...      ...
# 86495      1044      29.00      0.55      0.0       2.0  877     1900
# 86496    237021      35.00      0.13      0.0       2.0    1  1845000
# 86497     83366     121.75      0.32      0.0       2.0   10   257775
# 86498         0       0.00      0.00      0.0       2.0   43    14749
# 86499       903      24.75      0.05      0.0       2.0   65    18962
#
#        LotDepth  NumBldgs  NumFloors  OfficeArea  ResArea  ResidFAR  \
# ...

# %%
df4.to_csv("Q3.csv",index=False)

# %%
df4.corr()
# Out:
#             BldgArea  BldgDepth  BuiltFAR   CommFAR  FacilFAR       Lot  \
# BldgArea    1.000000   0.265288  0.293903  0.040977  0.096896  0.076667
# BldgDepth   0.265288   1.000000  0.268882  0.190147  0.280815 -0.005430
# BuiltFAR    0.293903   0.268882  1.000000  0.029249  0.257999  0.108780
# CommFAR     0.040977   0.190147  0.029249  1.000000  0.223809  0.004799
# FacilFAR    0.096896   0.280815  0.257999  0.223809  1.000000 -0.030049
# Lot         0.076667  -0.005430  0.108780  0.004799 -0.030049  1.000000
# LotArea     0.121790   0.032404 -0.004435  0.008210 -0.011638  0.007508
# LotDepth    0.265389   0.273199 -0.009360  0.089322 -0.009102  0.034654
# NumBldgs    0.488471   0.070834  0.089142 -0.012045 -0.040239  0.117228
# NumFloors   0.375063   0.376420  0.443195 -0.056011  0.289676  0.095749
# OfficeArea  0.240459   0.194356  0.042178  0.052681  0.042171  0.020724
# ResArea     0.929838   0.140366  0.273026 -0.008572  0.081319  0.067324
# ...

# %%
plt.figure(figsize=(20,15))
sns.heatmap(data=df4.corr(),cmap='coolwarm',annot=True)
plt.show()
