# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("darkgrid")


# %matplotlib inline

# %%
df = pd.read_csv("BX.csv", low_memory=False)

# %%
df
# Out:
#       Borough  Block   Lot   CD  CT2010  CB2010  SchoolDist  Council  ZipCode  \
# 0          BX   2260     1  201    19.0  1022.0         7.0      8.0  10454.0
# 1          BX   2260     4  201    19.0  1022.0         7.0      8.0  10454.0
# 2          BX   2260    10  201    19.0  1022.0         7.0      8.0  10454.0
# 3          BX   2260    17  201    19.0  1022.0         7.0      8.0  10454.0
# 4          BX   2260    18  201    19.0  1022.0         7.0      8.0  10454.0
# ...       ...    ...   ...  ...     ...     ...         ...      ...      ...
# 89849      BX   9999   100  204     NaN     NaN         NaN      NaN      NaN
# 89850      BX   9999   150  205     NaN     NaN         NaN      NaN      NaN
# 89851      BX   9999   200  205     NaN     NaN         NaN      NaN      NaN
# 89852      BX   9999  8900  209     NaN     NaN         NaN      NaN      NaN
# 89853      BX      0  8900  208     NaN     NaN         NaN      NaN      NaN
#
# ...

# %%
df = df[['Address', 'BldgArea', 'BldgDepth', 'BuiltFAR', 'CommFAR', 'FacilFAR', 'Lot', 'LotArea', 
         'LotDepth', 'NumBldgs', 'NumFloors', 'OfficeArea', 'ResArea', 'ResidFAR', 'RetailArea', 
         'YearBuilt', 'YearAlter1', 'ZipCode', 'YCoord', 'XCoord']]

# %%
df
# Out:
#                       Address  BldgArea  BldgDepth  BuiltFAR  CommFAR  \
# 0      122 BRUCKNER BOULEVARD         0        0.0      0.00      5.0
# 1      126 BRUCKNER BOULEVARD       752       16.0      0.05      5.0
# 2      138 BRUCKNER BOULEVARD     39375      200.0      1.13      5.0
# 3      144 BRUCKNER BOULEVARD     12500       85.0      5.00      5.0
# 4      148 BRUCKNER BOULEVARD      8595       70.0      4.58      5.0
# ...                       ...       ...        ...       ...      ...
# 89849                     NaN         0        0.0      0.00      0.0
# 89850                     NaN         0        0.0      0.00      3.4
# 89851                     NaN         0        0.0      0.00      0.0
# 89852                     NaN         0        0.0      0.00      0.0
# 89853                     NaN         0        0.0      0.00      0.0
#
#        FacilFAR   Lot  LotArea  LotDepth  NumBldgs  NumFloors  OfficeArea  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89854 entries, 0 to 89853
# Data columns (total 20 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Address     89785 non-null  object
#  1   BldgArea    89854 non-null  int64
#  2   BldgDepth   89854 non-null  float64
#  3   BuiltFAR    89854 non-null  float64
#  4   CommFAR     89854 non-null  float64
#  5   FacilFAR    89854 non-null  float64
#  6   Lot         89854 non-null  int64
#  7   LotArea     89854 non-null  int64
#  8   LotDepth    89854 non-null  float64
#  9   NumBldgs    89854 non-null  int64
#  10  NumFloors   89854 non-null  float64
#  11  OfficeArea  89854 non-null  int64
#  12  ResArea     89854 non-null  int64
#  13  ResidFAR    89854 non-null  float64
#  14  RetailArea  89854 non-null  int64
#  15  YearBuilt   89854 non-null  int64
#  16  YearAlter1  89854 non-null  int64
#  17  ZipCode     89525 non-null  float64
#  18  YCoord      86595 non-null  float64
# ...

# %%
df1 = df.copy()

# %%
df1
# Out:
#                       Address  BldgArea  BldgDepth  BuiltFAR  CommFAR  \
# 0      122 BRUCKNER BOULEVARD         0        0.0      0.00      5.0
# 1      126 BRUCKNER BOULEVARD       752       16.0      0.05      5.0
# 2      138 BRUCKNER BOULEVARD     39375      200.0      1.13      5.0
# 3      144 BRUCKNER BOULEVARD     12500       85.0      5.00      5.0
# 4      148 BRUCKNER BOULEVARD      8595       70.0      4.58      5.0
# ...                       ...       ...        ...       ...      ...
# 89849                     NaN         0        0.0      0.00      0.0
# 89850                     NaN         0        0.0      0.00      3.4
# 89851                     NaN         0        0.0      0.00      0.0
# 89852                     NaN         0        0.0      0.00      0.0
# 89853                     NaN         0        0.0      0.00      0.0
#
#        FacilFAR   Lot  LotArea  LotDepth  NumBldgs  NumFloors  OfficeArea  \
# ...

# %%
df1.dropna(inplace=True)

# %%
df1
# Out:
#                       Address  BldgArea  BldgDepth  BuiltFAR  CommFAR  \
# 0      122 BRUCKNER BOULEVARD         0       0.00      0.00      5.0
# 1      126 BRUCKNER BOULEVARD       752      16.00      0.05      5.0
# 2      138 BRUCKNER BOULEVARD     39375     200.00      1.13      5.0
# 3      144 BRUCKNER BOULEVARD     12500      85.00      5.00      5.0
# 4      148 BRUCKNER BOULEVARD      8595      70.00      4.58      5.0
# ...                       ...       ...        ...       ...      ...
# 89840   6007 RIVERDALE AVENUE      1044      29.00      0.55      0.0
# 89842   6301 RIVERDALE AVENUE    237021      35.00      0.13      0.0
# 89843     755 WEST 261 STREET     83366     121.75      0.32      0.0
# 89844    755 RIVERDALE AVENUE         0       0.00      0.00      0.0
# 89845    537A WEST 261 STREET       903      24.75      0.05      0.0
#
#        FacilFAR  Lot  LotArea  LotDepth  NumBldgs  NumFloors  OfficeArea  \
# ...

# %%
df1.columns
# Out:
# Index(['Address', 'BldgArea', 'BldgDepth', 'BuiltFAR', 'CommFAR', 'FacilFAR',
#        'Lot', 'LotArea', 'LotDepth', 'NumBldgs', 'NumFloors', 'OfficeArea',
#        'ResArea', 'ResidFAR', 'RetailArea', 'YearBuilt', 'YearAlter1',
#        'ZipCode', 'YCoord', 'XCoord'],
#       dtype='object')

# %%
df1.drop(['Address','YCoord', 'XCoord'],axis=1,inplace=True)

# %%
df1
# Out:
#        BldgArea  BldgDepth  BuiltFAR  CommFAR  FacilFAR  Lot  LotArea  \
# 0             0       0.00      0.00      5.0       6.5    1    15000
# 1           752      16.00      0.05      5.0       6.5    4    13770
# 2         39375     200.00      1.13      5.0       6.5   10    35000
# 3         12500      85.00      5.00      5.0       6.5   17     2500
# 4          8595      70.00      4.58      5.0       6.5   18     1875
# ...         ...        ...       ...      ...       ...  ...      ...
# 89840      1044      29.00      0.55      0.0       2.0  877     1900
# 89842    237021      35.00      0.13      0.0       2.0    1  1845000
# 89843     83366     121.75      0.32      0.0       2.0   10   257775
# 89844         0       0.00      0.00      0.0       2.0   43    14749
# 89845       903      24.75      0.05      0.0       2.0   65    18962
#
#        LotDepth  NumBldgs  NumFloors  OfficeArea  ResArea  ResidFAR  \
# ...

# %%
df2 = pd.read_csv("bronx.csv")

# %%
df2
# Out:
#                Complaint Type  ZipCode Borough
# 0              HEAT/HOT WATER  10458.0   BRONX
# 1              HEAT/HOT WATER  10456.0   BRONX
# 2              HEAT/HOT WATER  10459.0   BRONX
# 3        UNSANITARY CONDITION  10456.0   BRONX
# 4              HEAT/HOT WATER  10473.0   BRONX
# ...                       ...      ...     ...
# 1617951        HEAT/HOT WATER  10470.0   BRONX
# 1617952        HEAT/HOT WATER  10458.0   BRONX
# 1617953  UNSANITARY CONDITION  10472.0   BRONX
# 1617954        HEAT/HOT WATER  10461.0   BRONX
# 1617955        HEAT/HOT WATER  10467.0   BRONX
#
# [1617956 rows x 3 columns]

# %%
df2.columns
# Out:
# Index(['Complaint Type', 'ZipCode', 'Borough'], dtype='object')

# %%
df2.drop(['Borough'],axis=1,inplace=True)

# %%
df2
# Out:
#                Complaint Type  ZipCode
# 0              HEAT/HOT WATER  10458.0
# 1              HEAT/HOT WATER  10456.0
# 2              HEAT/HOT WATER  10459.0
# 3        UNSANITARY CONDITION  10456.0
# 4              HEAT/HOT WATER  10473.0
# ...                       ...      ...
# 1617951        HEAT/HOT WATER  10470.0
# 1617952        HEAT/HOT WATER  10458.0
# 1617953  UNSANITARY CONDITION  10472.0
# 1617954        HEAT/HOT WATER  10461.0
# 1617955        HEAT/HOT WATER  10467.0
#
# [1617956 rows x 2 columns]

# %%
#duplicateDFRow = df2[df2.duplicated()]

# %%
#duplicateDFRow

# %%
#df2.drop_duplicates(ignore_index=True, inplace=True)

# %%
#df2

# %%
#df2.info()

# %%
df2['Complaint Type'].value_counts()

# %%
df1.info()

# %% [markdown]
# ### Using JOIN Method

# %%
joined_df = df1.join(df2,on='ZipCode', how='left',lsuffix='ZipCodeLeft',rsuffix='ZipCodeRight')

# %%
joined_df
# Out:
#        BldgArea  BldgDepth  BuiltFAR  CommFAR  FacilFAR  Lot  LotArea  \
# 0             0       0.00      0.00      5.0       6.5    1    15000
# 1           752      16.00      0.05      5.0       6.5    4    13770
# 2         39375     200.00      1.13      5.0       6.5   10    35000
# 3         12500      85.00      5.00      5.0       6.5   17     2500
# 4          8595      70.00      4.58      5.0       6.5   18     1875
# ...         ...        ...       ...      ...       ...  ...      ...
# 89840      1044      29.00      0.55      0.0       2.0  877     1900
# 89842    237021      35.00      0.13      0.0       2.0    1  1845000
# 89843     83366     121.75      0.32      0.0       2.0   10   257775
# 89844         0       0.00      0.00      0.0       2.0   43    14749
# 89845       903      24.75      0.05      0.0       2.0   65    18962
#
#        LotDepth  NumBldgs  NumFloors  OfficeArea  ResArea  ResidFAR  \
# ...

# %%
joined_df['Complaint Type'].value_counts()
# Out:
# UNSANITARY CONDITION    23955
# PAINT/PLASTER           18098
# HEAT/HOT WATER          10118
# WATER LEAK              10001
# GENERAL                  8865
# DOOR/WINDOW              8831
# ELECTRIC                 2805
# FLOORING/STAIRS          2269
# PLUMBING                 1649
# Name: Complaint Type, dtype: int64

# %%
joined_df.columns
# Out:
# Index(['BldgArea', 'BldgDepth', 'BuiltFAR', 'CommFAR', 'FacilFAR', 'Lot',
#        'LotArea', 'LotDepth', 'NumBldgs', 'NumFloors', 'OfficeArea', 'ResArea',
#        'ResidFAR', 'RetailArea', 'YearBuilt', 'YearAlter1',
#        'ZipCodeZipCodeLeft', 'Complaint Type', 'ZipCodeZipCodeRight'],
#       dtype='object')

# %%
joined_df.isnull().sum()
# Out:
# BldgArea               0
# BldgDepth              0
# BuiltFAR               0
# CommFAR                0
# FacilFAR               0
# Lot                    0
# LotArea                0
# LotDepth               0
# NumBldgs               0
# NumFloors              0
# OfficeArea             0
# ResArea                0
# ResidFAR               0
# RetailArea             0
# YearBuilt              0
# YearAlter1             0
# ZipCodeZipCodeLeft     0
# Complaint Type         0
# ZipCodeZipCodeRight    0
# dtype: int64

# %%
joined_df.drop(['YearBuilt', 'YearAlter1','ZipCodeZipCodeLeft','ZipCodeZipCodeRight'],axis=1,inplace=True)

# %%
joined_df
# Out:
#        BldgArea  BldgDepth  BuiltFAR  CommFAR  FacilFAR  Lot  LotArea  \
# 0             0       0.00      0.00      5.0       6.5    1    15000
# 1           752      16.00      0.05      5.0       6.5    4    13770
# 2         39375     200.00      1.13      5.0       6.5   10    35000
# 3         12500      85.00      5.00      5.0       6.5   17     2500
# 4          8595      70.00      4.58      5.0       6.5   18     1875
# ...         ...        ...       ...      ...       ...  ...      ...
# 89840      1044      29.00      0.55      0.0       2.0  877     1900
# 89842    237021      35.00      0.13      0.0       2.0    1  1845000
# 89843     83366     121.75      0.32      0.0       2.0   10   257775
# 89844         0       0.00      0.00      0.0       2.0   43    14749
# 89845       903      24.75      0.05      0.0       2.0   65    18962
#
#        LotDepth  NumBldgs  NumFloors  OfficeArea  ResArea  ResidFAR  \
# ...

# %%
joined_df.describe()
# Out:
#            BldgArea     BldgDepth      BuiltFAR       CommFAR      FacilFAR  \
# count  8.659100e+04  86591.000000  86591.000000  86591.000000  86591.000000
# mean   8.341031e+03     49.855709      1.143734      0.123250      2.870513
# std    6.625799e+04     30.325272      1.810324      0.561512      1.597633
# min    0.000000e+00      0.000000      0.000000      0.000000      0.000000
# 25%    1.665000e+03     35.000000      0.590000      0.000000      2.000000
# 50%    2.280000e+03     45.000000      0.880000      0.000000      2.000000
# 75%    3.321000e+03     56.000000      1.270000      0.000000      4.800000
# max    1.354011e+07   1300.000000    259.800000      9.000000     10.000000
#
#                 Lot       LotArea      LotDepth      NumBldgs     NumFloors  \
# count  86591.000000  8.659100e+04  86591.000000  86591.000000  86591.000000
# mean     105.260893  9.479385e+03    104.972907      1.224896      2.350154
# ...

# %% [markdown]
# ### Let HEAT/HOT WATER be 1 and the rest 0 for binary classification

# %%
df3 = joined_df.copy()

# %%
df3
# Out:
#        BldgArea  BldgDepth  BuiltFAR  CommFAR  FacilFAR  Lot  LotArea  \
# 0             0       0.00      0.00      5.0       6.5    1    15000
# 1           752      16.00      0.05      5.0       6.5    4    13770
# 2         39375     200.00      1.13      5.0       6.5   10    35000
# 3         12500      85.00      5.00      5.0       6.5   17     2500
# 4          8595      70.00      4.58      5.0       6.5   18     1875
# ...         ...        ...       ...      ...       ...  ...      ...
# 89840      1044      29.00      0.55      0.0       2.0  877     1900
# 89842    237021      35.00      0.13      0.0       2.0    1  1845000
# 89843     83366     121.75      0.32      0.0       2.0   10   257775
# 89844         0       0.00      0.00      0.0       2.0   43    14749
# 89845       903      24.75      0.05      0.0       2.0   65    18962
#
#        LotDepth  NumBldgs  NumFloors  OfficeArea  ResArea  ResidFAR  \
# ...

# %%
df3['Complaint Type'].unique()
# Out:
# array(['PLUMBING', 'DOOR/WINDOW', 'WATER LEAK', 'PAINT/PLASTER',
#        'GENERAL', 'HEAT/HOT WATER', 'ELECTRIC', 'UNSANITARY CONDITION',
#        'FLOORING/STAIRS'], dtype=object)

# %%
df3['Complaint Type'].replace(to_replace='PLUMBING',value=0,inplace=True)

# %%
df3['Complaint Type'].replace(to_replace='DOOR/WINDOW',value=0,inplace=True)

# %%
df3['Complaint Type'].replace(to_replace='WATER LEAK',value=0,inplace=True)

# %%
df3['Complaint Type'].replace(to_replace='PAINT/PLASTER',value=0,inplace=True)

# %%
df3['Complaint Type'].replace(to_replace='GENERAL',value=0,inplace=True)

# %%
df3['Complaint Type'].replace(to_replace='HEAT/HOT WATER',value=1,inplace=True)

# %%
df3['Complaint Type'].replace(to_replace='ELECTRIC',value=0,inplace=True)

# %%
df3['Complaint Type'].replace(to_replace='UNSANITARY CONDITION',value=0,inplace=True)

# %%
df3['Complaint Type'].replace(to_replace='FLOORING/STAIRS',value=0,inplace=True)

# %%
df3['Complaint Type'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df3['Complaint Type'].value_counts()
# Out:
# 0    76473
# 1    10118
# Name: Complaint Type, dtype: int64

# %%
df3
# Out:
#        BldgArea  BldgDepth  BuiltFAR  CommFAR  FacilFAR  Lot  LotArea  \
# 0             0       0.00      0.00      5.0       6.5    1    15000
# 1           752      16.00      0.05      5.0       6.5    4    13770
# 2         39375     200.00      1.13      5.0       6.5   10    35000
# 3         12500      85.00      5.00      5.0       6.5   17     2500
# 4          8595      70.00      4.58      5.0       6.5   18     1875
# ...         ...        ...       ...      ...       ...  ...      ...
# 89840      1044      29.00      0.55      0.0       2.0  877     1900
# 89842    237021      35.00      0.13      0.0       2.0    1  1845000
# 89843     83366     121.75      0.32      0.0       2.0   10   257775
# 89844         0       0.00      0.00      0.0       2.0   43    14749
# 89845       903      24.75      0.05      0.0       2.0   65    18962
#
#        LotDepth  NumBldgs  NumFloors  OfficeArea  ResArea  ResidFAR  \
# ...

# %%
#df3.to_csv("final.csv",index=False)

# %% [markdown]
# ### Using Merge Method

# %%
df3 = pd.merge(left=df1,right=df2,how='inner',on="ZipCode")

# %%
df3

# %%
df3.isnull().sum()

# %%
duplicateDFRow = df3[df3.duplicated()]

# %%
duplicateDFRow

# %%
df3.drop_duplicates(ignore_index=True, inplace=True)

# %%
df3

# %%
df3.groupby(by="ZipCode", as_index=False).count()

# %%
df3.groupby(by="Complaint Type", as_index=False).count()

# %%
df4 = df3.copy()

# %%
df4

# %%
df4.drop(['Street Name'],axis=1,inplace=True)

# %%
df4

# %%
duplicateDFRow = df4[df4.duplicated()]

# %%
duplicateDFRow

# %%
df4.drop_duplicates(ignore_index=True, inplace=True)

# %%
df4

# %%
df4.to_csv("Q3.csv",index=False)

# %%
df4.corr()

# %%
plt.figure(figsize=(20,15))
sns.heatmap(data=df4.corr(),cmap='coolwarm',annot=True)
plt.show()
